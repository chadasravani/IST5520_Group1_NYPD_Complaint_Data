# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
import seaborn as sns

# %%
#Import Dataset
df = pd.read_csv('../NYPD_Complaint_Data_Current__Year_To_Date.csv')
df.head()
# Out:
#   CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0  244685801           69       BROOKLYN   01/01/2015     00:00:00
# 1  242250195           42          BRONX   03/17/2022     15:23:00
# 2  242385774          123  STATEN ISLAND   03/20/2022     11:52:00
# 3  242643555          121  STATEN ISLAND   03/24/2022     15:00:00
# 4  242816732           42          BRONX   03/29/2022     15:24:00
#
#   CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  ...  \
# 0          NaN       (null)        COMPLETED     (null)          NaN  ...
# 1   03/17/2022     15:28:00        ATTEMPTED     (null)          NaN  ...
# 2          NaN       (null)        COMPLETED     (null)          NaN  ...
# 3   03/24/2022     22:00:00        COMPLETED     (null)          NaN  ...
# 4   03/29/2022     15:30:00        COMPLETED     (null)          NaN  ...
#
#    TRANSIT_DISTRICT VIC_AGE_GROUP  VIC_RACE VIC_SEX X_COORD_CD Y_COORD_CD  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256797 entries, 0 to 256796
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   CMPLNT_NUM                256797 non-null  object
#  1   ADDR_PCT_CD               256797 non-null  int64
#  2   BORO_NM                   256797 non-null  object
#  3   CMPLNT_FR_DT              256797 non-null  object
#  4   CMPLNT_FR_TM              256797 non-null  object
#  5   CMPLNT_TO_DT              237423 non-null  object
#  6   CMPLNT_TO_TM              256797 non-null  object
#  7   CRM_ATPT_CPTD_CD          256797 non-null  object
#  8   HADEVELOPT                256797 non-null  object
#  9   HOUSING_PSA               16985 non-null   float64
#  10  JURISDICTION_CODE         256797 non-null  int64
#  11  JURIS_DESC                256797 non-null  object
#  12  KY_CD                     256797 non-null  int64
# ...

# %%
df.shape
# Out:
# (256797, 36)

# %%
df.isnull().sum()
# Out:
# CMPLNT_NUM                       0
# ADDR_PCT_CD                      0
# BORO_NM                          0
# CMPLNT_FR_DT                     0
# CMPLNT_FR_TM                     0
# CMPLNT_TO_DT                 19374
# CMPLNT_TO_TM                     0
# CRM_ATPT_CPTD_CD                 0
# HADEVELOPT                       0
# HOUSING_PSA                 239812
# JURISDICTION_CODE                0
# JURIS_DESC                       0
# KY_CD                            0
# LAW_CAT_CD                       0
# LOC_OF_OCCUR_DESC                0
# OFNS_DESC                        0
# PARKS_NM                         0
# PATROL_BORO                      0
# PD_CD                          269
# PD_DESC                          0
# PREM_TYP_DESC                    0
# RPT_DT                           0
# STATION_NAME                     0
# SUSP_AGE_GROUP                   0
# SUSP_RACE                        0
# SUSP_SEX                         0
# TRANSIT_DISTRICT            251089
# ...

# %%
df.drop(columns=['HOUSING_PSA','TRANSIT_DISTRICT'],inplace= True)

# %%
df.replace('(null)',np.nan,inplace= True)

# %%
df.isna().sum()
# Out:
# CMPLNT_NUM                       0
# ADDR_PCT_CD                      0
# BORO_NM                        441
# CMPLNT_FR_DT                     0
# CMPLNT_FR_TM                     0
# CMPLNT_TO_DT                 19374
# CMPLNT_TO_TM                 19319
# CRM_ATPT_CPTD_CD                 0
# HADEVELOPT                  255982
# JURISDICTION_CODE                0
# JURIS_DESC                       0
# KY_CD                            0
# LAW_CAT_CD                       0
# LOC_OF_OCCUR_DESC            41066
# OFNS_DESC                        6
# PARKS_NM                    255376
# PATROL_BORO                      4
# PD_CD                          269
# PD_DESC                        269
# PREM_TYP_DESC                  107
# RPT_DT                           0
# STATION_NAME                251089
# SUSP_AGE_GROUP               50792
# SUSP_RACE                    50792
# SUSP_SEX                     50792
# VIC_AGE_GROUP                    0
# VIC_RACE                        72
# ...

# %%
df.drop(columns=['HADEVELOPT','PARKS_NM', 'STATION_NAME'],inplace= True)

# %%
df.shape
# Out:
# (256797, 31)

# %%
df.drop_duplicates(inplace = True)

# %%
df.fillna(np.nan,inplace = True)

# %%
df.dropna()
# Out:
#        CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 1       242250195           42          BRONX   03/17/2022     15:23:00
# 3       242643555          121  STATEN ISLAND   03/24/2022     15:00:00
# 4       242816732           42          BRONX   03/29/2022     15:24:00
# 6       238863220           25      MANHATTAN   12/31/2021     21:45:00
# 7       242870934           46          BRONX   03/16/2018     12:00:00
# ...           ...          ...            ...          ...          ...
# 256785  247415547           67       BROOKLYN   06/30/2022     07:30:00
# 256787  247392103           40          BRONX   06/30/2022     18:05:00
# 256791  247392173          109         QUEENS   06/30/2022     18:38:00
# 256792  247399166           33      MANHATTAN   06/30/2022     22:10:00
# 256795  247434393          109         QUEENS   06/30/2022     14:30:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD  JURISDICTION_CODE  \
# ...

# %%
df.dropna()
# Out:
#        CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 1       242250195           42          BRONX   03/17/2022     15:23:00
# 3       242643555          121  STATEN ISLAND   03/24/2022     15:00:00
# 4       242816732           42          BRONX   03/29/2022     15:24:00
# 6       238863220           25      MANHATTAN   12/31/2021     21:45:00
# 7       242870934           46          BRONX   03/16/2018     12:00:00
# ...           ...          ...            ...          ...          ...
# 256785  247415547           67       BROOKLYN   06/30/2022     07:30:00
# 256787  247392103           40          BRONX   06/30/2022     18:05:00
# 256791  247392173          109         QUEENS   06/30/2022     18:38:00
# 256792  247399166           33      MANHATTAN   06/30/2022     22:10:00
# 256795  247434393          109         QUEENS   06/30/2022     14:30:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD  JURISDICTION_CODE  \
# ...

# %%
df.drop(columns=['Lat_Lon', 'New Georeferenced Column'], inplace= True)

# %%
df
# Out:
#        CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0       244685801           69       BROOKLYN   01/01/2015     00:00:00
# 1       242250195           42          BRONX   03/17/2022     15:23:00
# 2       242385774          123  STATEN ISLAND   03/20/2022     11:52:00
# 3       242643555          121  STATEN ISLAND   03/24/2022     15:00:00
# 4       242816732           42          BRONX   03/29/2022     15:24:00
# ...           ...          ...            ...          ...          ...
# 256792  247399166           33      MANHATTAN   06/30/2022     22:10:00
# 256793  247392181          113         QUEENS   06/30/2022     19:26:00
# 256794  247383348           90       BROOKLYN   06/30/2022     12:36:00
# 256795  247434393          109         QUEENS   06/30/2022     14:30:00
# 256796  247376531           18      MANHATTAN   06/30/2022     12:57:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD  JURISDICTION_CODE  \
# ...

# %%
df.SUSP_AGE_GROUP.unique()
# Out:
# array(['18-24', 'UNKNOWN', '25-44', nan, '45-64', '<18', '65+', '-74',
#        '-969', '2022', '-1', '-5962', '-961', '-10', '-941'], dtype=object)

# %%
df.SUSP_RACE.unique()
# Out:
# array(['UNKNOWN', 'BLACK', nan, 'WHITE HISPANIC', 'WHITE',
#        'ASIAN / PACIFIC ISLANDER', 'BLACK HISPANIC',
#        'AMERICAN INDIAN/ALASKAN NATIVE'], dtype=object)

# %%
df.SUSP_RACE.value_counts()['UNKNOWN']
# Out:
# 62985

# %%
df.VIC_AGE_GROUP.unique()
# Out:
# array(['<18', 'UNKNOWN', '45-64', '18-24', '25-44', '65+', '-11', '-5',
#        '-934', '-960', '-65', '-970', '-40', '-971', '-4', '-964', '-955',
#        '-959', '-963'], dtype=object)

# %%
df.VIC_AGE_GROUP.value_counts()[['UNKNOWN','-11', '-5','-934', '-960', '-65', '-970', '-40', '-971', '-4', '-964', '-955','-959', '-963']]
# Out:
# UNKNOWN    72688
# -11            1
# -5             2
# -934           1
# -960           1
# -65            2
# -970           1
# -40            1
# -971           1
# -4             1
# -964           1
# -955           1
# -959           1
# -963           1
# Name: VIC_AGE_GROUP, dtype: int64

# %%
df.VIC_RACE.unique()
# Out:
# array(['BLACK', 'UNKNOWN', 'WHITE', 'WHITE HISPANIC', 'BLACK HISPANIC',
#        'ASIAN / PACIFIC ISLANDER', 'AMERICAN INDIAN/ALASKAN NATIVE', nan],
#       dtype=object)

# %%
df.VIC_RACE.value_counts()['UNKNOWN']
# Out:
# 77580

# %%
df.SUSP_AGE_GROUP.value_counts()['-74']
# Out:
# 1

# %%
df.SUSP_AGE_GROUP.value_counts()['-1']
# Out:
# 1

# %%
df.SUSP_AGE_GROUP.value_counts()['-5962']
# Out:
# 1

# %%
df.SUSP_AGE_GROUP.value_counts()['-961']
# Out:
# 1

# %%
df.SUSP_AGE_GROUP.value_counts()['-10']
# Out:
# 1

# %%
df.SUSP_AGE_GROUP.value_counts()['-941']
# Out:
# 1

# %%
df.SUSP_AGE_GROUP.value_counts()['UNKNOWN']
# Out:
# 96968

# %%
indexAge = df[ (df['SUSP_AGE_GROUP'] == 'UNKNOWN') ].index
df.drop(indexAge , inplace=True)

# %%
df.shape
# Out:
# (159829, 29)

# %%
indexAge1 = df[ (df['VIC_AGE_GROUP'] == 'UNKNOWN') ].index
df.drop(indexAge1 , inplace=True)

# %%
df.shape
# Out:
# (113488, 29)

# %%
indexAge3 = df[ (df['SUSP_RACE'] == 'UNKNOWN') ].index
df.drop(indexAge3 , inplace=True)
df.shape
# Out:
# (109575, 29)

# %%
indexAge4 = df[ (df['VIC_RACE'] == 'UNKNOWN') ].index
df.drop(indexAge4 , inplace=True)
df.shape
# Out:
# (105932, 29)

# %%
# Show descriptive statistics
df.describe().transpose()
# Out:
#                       count          mean           std            min  \
# ADDR_PCT_CD        105932.0  6.771407e+01     33.228178       1.000000
# JURISDICTION_CODE  105932.0  4.069686e-01      4.348423       0.000000
# KY_CD              105932.0  3.182076e+02    169.205191     101.000000
# PD_CD              105666.0  3.822025e+02    228.262161     100.000000
# X_COORD_CD         105932.0  1.006778e+06  21999.720938  914465.000000
# Y_COORD_CD         105932.0  2.072426e+05  31072.861439  121312.000000
# Latitude           105932.0  4.073546e+01      0.085289      40.499393
# Longitude          105932.0 -7.391868e+01      0.079341     -74.250939
#
#                              25%           50%           75%           max
# ADDR_PCT_CD            43.000000  6.900000e+01  1.030000e+02  1.230000e+02
# JURISDICTION_CODE       0.000000  0.000000e+00  0.000000e+00  9.700000e+01
# KY_CD                 118.000000  3.440000e+02  3.610000e+02  6.780000e+02
# ...

# %%
df.corr()
# Out:
#                    ADDR_PCT_CD  JURISDICTION_CODE     KY_CD     PD_CD  \
# ADDR_PCT_CD           1.000000          -0.041761 -0.012067  0.013662
# JURISDICTION_CODE    -0.041761           1.000000  0.000034 -0.020291
# KY_CD                -0.012067           0.000034  1.000000  0.493468
# PD_CD                 0.013662          -0.020291  0.493468  1.000000
# X_COORD_CD            0.171175          -0.003183 -0.026745 -0.019292
# Y_COORD_CD           -0.491698           0.025475 -0.009261 -0.009261
# Latitude             -0.492080           0.025488 -0.009261 -0.009276
# Longitude             0.170902          -0.003169 -0.026745 -0.019245
#
#                    X_COORD_CD  Y_COORD_CD  Latitude  Longitude
# ADDR_PCT_CD          0.171175   -0.491698 -0.492080   0.170902
# JURISDICTION_CODE   -0.003183    0.025475  0.025488  -0.003169
# KY_CD               -0.026745   -0.009261 -0.009261  -0.026745
# PD_CD               -0.019292   -0.009261 -0.009276  -0.019245
# ...

# %%
from sklearn import preprocessing

# %%
# Scale the dataset into [0,1]
scaler1 = preprocessing.MinMaxScaler().fit(df[['ADDR_PCT_CD',
                                                 'JURISDICTION_CODE',
                                                 'KY_CD',
                                                 'PD_CD','X_COORD_CD','Y_COORD_CD','Latitude','Longitude']])

df_scale = scaler1.transform(df[['ADDR_PCT_CD',
                                                 'JURISDICTION_CODE',
                                                 'KY_CD',
                                                 'PD_CD','X_COORD_CD','Y_COORD_CD','Latitude','Longitude']])

# %%
type(df_scale)
# Out:
# numpy.ndarray

# %%
import pandas as pd
df_scale = pd.DataFrame(df_scale,columns=['ADDR_PCT_CD',
                                              'JURISDICTION_CODE',
                                              'KY_CD',
                                              'PD_CD','X_COORD_CD','Y_COORD_CD','Latitude','Longitude'])

# %%
type(df_scale)
# Out:
# pandas.core.frame.DataFrame

# %%
df_scale.describe().transpose()
# Out:
#                       count      mean       std  min       25%       50%  \
# ADDR_PCT_CD        105932.0  0.546837  0.272362  0.0  0.344262  0.557377
# JURISDICTION_CODE  105932.0  0.004196  0.044829  0.0  0.000000  0.000000
# KY_CD              105932.0  0.376443  0.293250  0.0  0.029463  0.421144
# PD_CD              105666.0  0.343312  0.277691  0.0  0.018248  0.306569
# X_COORD_CD         105932.0  0.604294  0.144014  0.0  0.531294  0.602713
# Y_COORD_CD         105932.0  0.570941  0.206455  0.0  0.415157  0.560270
# Latitude           105932.0  0.571136  0.206351  0.0  0.415505  0.560386
# Longitude          105932.0  0.603703  0.144159  0.0  0.530461  0.602221
#
#                         75%  max
# ADDR_PCT_CD        0.836066  1.0
# JURISDICTION_CODE  0.000000  1.0
# KY_CD              0.450607  1.0
# PD_CD              0.654501  1.0
# X_COORD_CD         0.685378  1.0
# Y_COORD_CD         0.764828  1.0
# Latitude           0.764960  1.0
# Longitude          0.684871  1.0

# %% [markdown]
# From the above descriptive statistics, we can see that the four numerical columns in the scaled dataset have been scaled to the range of [0,1].
